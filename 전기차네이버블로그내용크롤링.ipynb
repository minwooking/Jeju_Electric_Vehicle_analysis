# %% [markdown]
# ## Use lib

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from bs4 import BeautifulSoup
from urllib.parse import quote
import urllib.request
import requests
import urllib.parse 
from urllib import parse
import ssl

context = ssl._create_unverified_context()

# %%
#iframe 제거 후 blog.naver.com 붙이기
def delete_iframe(url):
    headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.93 Safari/537.36"}
    res = requests.get(url, headers=headers)
    res.raise_for_status() # 문제시 프로그램 종료
    soup = BeautifulSoup(res.text, "lxml") 

    src_url = "https://blog.naver.com/" + soup.iframe["src"]
    
    return src_url

# %% [markdown]
# ## Use Data

# %%
df = pd.read_csv('G:\내 드라이브\제주_전기차\data\네이버블로그감성분석비교.csv')

# %%
df['감성사전긍부정'] = df['긍부정'].apply(lambda x: 'P' if ( x > 0) else 
                                    'N' if (x < 0) else 
                                   'E' if ( x== 0) else 
                                    '미분류')

# %%
df.head(2)
# Out:
#    Unnamed: 0                                           제목          날짜  \
# 0           0                    [2022/3/17]오늘의 증권사 리포트 정리  2022.03.17
# 1           1  2022년 4박 5일 신혼여행 후기 ing 제주도 (Feat. 일오반식당...  2022.03.17
#
#                                                   내용  긍부정  \
# 0     종목명   삼성전기    시총액억    투견    후기 안정적인 오피스 기반 ...    1
# 1  제주도신혼여행후기내돈내산년 년 월 일 드뎌 결혼식이 끝나고 우도 가자마자 전기차를 ...    0
#
#                                                 href  year lr긍부정 lr긍부정이진분류
# 0  https://blog.naver.com/unicornup?Redirect=Log&...  2022     E         P
# 1  https://blog.naver.com/apple_378?Redirect=Log&...  2022     E         P

# %%
df.href[0]
# Out:
# 'https://blog.naver.com/unicornup?Redirect=Log&logNo=222675376585'

# %%
search = '제주전기차'
url = 'https://search.naver.com/search.naver?where=post&sm=tab_jum&query=' 
newurl = delete_iframe(df.href[0])

# %%
newurl = delete_iframe(df.href[0])
html = urllib.request.urlopen(newurl).read()
soup = BeautifulSoup(html,'html.parser')

# %%
html

# %%
c

# %%
soup
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
#
# <html lang="ko">
# <head>
# <meta content="no-cache" http-equiv="Pragma"/>
# <meta content="-1" http-equiv="Expires"/>
# <meta content="always" name="referrer"/>
# <!--[if ie]>
# <style type="text/css">
# html {overflow: scroll; overflow-x: auto;}
# </style>
# <![endif]-->
# <link charset="UTF-8" href="https://ssl.pstatic.net/t.static.blog/mylog/versioning/LayoutTopCommon-585283351_https.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/t.static.blog/mylog/versioning//common/css/music/player-d3fc09e_https.css" rel="stylesheet" type="text/css"/>
# <link href="/favicon.ico?3" rel="shortcut icon" type="image/x-icon">
# <meta content="[2022/3/17]오늘의 증권사 리포트 정리" property="og:title"/>
# ...

# %%
soup.find_all('p')[0].text
# Out:
# '오늘 있었던 일을 퀵에디터로 기록해보세요.'

# %%
contents=  ''
content=list(soup.find_all('div',class_='se-module se-module-text'))
for i,item in enumerate(list(soup.find_all('div',class_='se-module se-module-text'))):
    if item.text.__contains__('전기차'):
        contents += (content[i-2].text+content[i-i].text+item.text+content[i+1].text+content[i+2].text)

# %%
print(contents)
# Out:
#  - 현재가(원)          : 8370 (2.07%)
# 안녕하세요. 오늘의 리포트서머리 요약 정보 올려드리겠습니다.리포트 발행 건수가 많은 종목 순서대로 정리하였습니다.
#  - 제목 [ 내연기관차 부품부터 전기차 부품까지 ] - 요약▶ 기업개요: 자동차 사출부품 제조업체

# %%
contentss = []
for  i  in range(len(df.href[3])):
    newurl = delete_iframe(df.href[i])
    html = urllib.request.urlopen(newurl).read()
    soup = BeautifulSoup(html,'html.parser')
    contents=  ''
    content=list(soup.find_all('div',class_='se-module se-module-text'))
    for i,item in enumerate(list(soup.find_all('div',class_='se-module se-module-text'))):
        if item.text.__contains__('전기차'):
            if i < 2 :
                contents += (item.text)
            else:
                contents += (content[i-2].text+content[i-i].text+item.text+content[i+1].text+content[i+2].text)
        contentss.append(contents)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19136/4256018300.py in <module>
#      11                 contents += (item.text)
#      12             else:
# ---> 13                 contents += (content[i-2].text+content[i-i].text+item.text+content[i+1].text+content[i+2].text)
#      14         contentss.append(contents)
#      15
#
# IndexError: list index out of range

# %%
len(contentss)
# Out:
# 1711

# %%
    for i,item in enumerate(list(soup.find_all('div',class_='se-module se-module-text'))):
        if item.text.__contains__('전기차'):
                contents += (item.text)
                contents += (content[i-2].text+content[i-i].text+item.text+content[i+1].text+content[i+2].text)
                contentss.append(contents)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6452/3191188712.py in <module>
#       4             contents += (item.text)
#       5         else:
# ----> 6             contents += (content[i-2].text+content[i-i].text+item.text+content[i+1].text+content[i+2].text)
#       7             contentss.append(contents)
#
# IndexError: list index out of range

# %%
list(soup.find_all('div',class_='se-module se-module-text'))[0].text.__contains__('충전')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19136/258668158.py in <module>
# ----> 1 list(soup.find_all('div',class_='se-module se-module-text'))[0].text.__contains__('충전')
#
# NameError: name 'soup' is not defined

# %%
contentss
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
# ...
